# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadbadi/Clustering_Frequency/blob/main/Code%20Sections/5.6.1%20DBSCAN%20EPS%20%2B%20Min%20Sample%20Tuning%20Stage%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **STAGE 1 - Coarse Tuning  - wider jumps of eps and min sample**

# %%
                                                                                  # Parallel Processing Setup: Process 5 chunks per run
start_chunk = 26                                                                  # Set these variables for each run. Edit as needed (1-indexed)
num_chunks_to_process = 5
end_chunk = start_chunk + num_chunks_to_process - 1

feature_df = pd.read_csv("Feature_Combo_All_with_set_number.csv")                 # Load the previously saved feature combinations CSV.

import math                                                                       # Split the list of feature sets into chunks of 143 sets.
all_combinations = feature_df['features'].apply(eval).tolist()                    # Convert string repr back to list
chunk_size = 143
chunks = [all_combinations[i:i + chunk_size] for i in range(0, len(all_combinations), chunk_size)]
total_chunks = len(chunks)

if start_chunk < 1 or start_chunk > total_chunks:
    raise ValueError("start_chunk must be between 1 and total number of chunks")
if end_chunk > total_chunks:
    end_chunk = total_chunks

print(f"Processing chunks from {start_chunk} to {end_chunk} (each with 143 sets)")

url = "https://raw.githubusercontent.com/mohammadbadi/Clustering_Frequency/refs/heads/main/Output_CSV/FE_Encoded_New.csv" # Load the Dataset (10% sample)
data = pd.read_csv(url)
data = data.sample(frac=0.1, random_state=42)

import numpy as np                                                                # STAGE 1 - Coarse Tuning for Selected Chunks
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from google.colab import files

eps_values_coarse = np.array([1, 2, 3, 4, 5])
min_samples_values_coarse = [5, 10, 15]

for chunk_index in range(start_chunk, end_chunk+1):                               # Process each chunk in the specified range.
    chunk = chunks[chunk_index - 1]                                               # converting 1-indexed to 0-indexed
    results = []
    for local_set_number, feature_set in enumerate(chunk, start=1):               # Process each set in the current chunk.
        global_set_number = (chunk_index - 1) * chunk_size + local_set_number     # Compute global set_number for clarity.

        missing_features = [feat for feat in feature_set if feat not in data.columns]
        if missing_features:                                                      # If features are missing, record a row with Nones.
            results.append({
                "set_number": global_set_number,
                "features": feature_set,
                "best_eps": None,
                "best_min_samples": None,
                "best_silhouette_score": None,
                "top10_eps": None,
                "top10_min_samples": None,
                "top10_eps_min": None,
                "top10_eps_max": None,
                "top10_min_samples_min": None,
                "top10_min_samples_max": None
            })
            print(f"Set {global_set_number} evaluated. Missing features: {missing_features}")
            continue

        df_subset = data[feature_set]
        scaler = StandardScaler()
        df_subset = pd.DataFrame(scaler.fit_transform(df_subset), columns=df_subset.columns)

        score_list = []
        for eps in eps_values_coarse:
            for min_samples in min_samples_values_coarse:
                try:
                    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
                    labels = dbscan.fit_predict(df_subset)                        # Only consider valid clustering results (at least 2 clusters and some non-noise labels)
                    if len(set(labels)) > 1 and any(label != -1 for label in labels):
                        score = silhouette_score(df_subset, labels)
                        score_list.append((score, eps, min_samples))
                except Exception:
                    continue

        if score_list:
            score_list.sort(key=lambda x: x[0], reverse=True)
            top_10 = score_list[:10]
            top10_eps = [entry[1] for entry in top_10]
            top10_min_samples = [entry[2] for entry in top_10]
            eps_range = (min(top10_eps), max(top10_eps))
            min_samples_range = (min(top10_min_samples), max(top10_min_samples))
            best_score, best_eps, best_min_samples = top_10[0]

            results.append({
                "set_number": global_set_number,
                "features": feature_set,
                "best_eps": best_eps,
                "best_min_samples": best_min_samples,
                "best_silhouette_score": best_score,
                "top10_eps": str(top10_eps),
                "top10_min_samples": str(top10_min_samples),
                "top10_eps_min": eps_range[0],
                "top10_eps_max": eps_range[1],
                "top10_min_samples_min": min_samples_range[0],
                "top10_min_samples_max": min_samples_range[1]
            })
            print(f"Set {global_set_number} evaluated. Best: (eps: {best_eps}, min_samples: {best_min_samples}), Score: {best_score:.4f}")
        else:
            results.append({
                "set_number": global_set_number,
                "features": feature_set,
                "best_eps": None,
                "best_min_samples": None,
                "best_silhouette_score": None,
                "top10_eps": None,
                "top10_min_samples": None,
                "top10_eps_min": None,
                "top10_eps_max": None,
                "top10_min_samples_min": None,
                "top10_min_samples_max": None
            })
            print(f"Set {global_set_number} evaluated. No valid clustering found.")

    results_df = pd.DataFrame(results)                                            # Save results for the current chunk.
    output_filename = f"DBSCAN_Coarse_Top10_chunk_{chunk_index}.csv"
    results_df.to_csv(output_filename, index=False)
    print(f"Chunk {chunk_index} processed and saved to '{output_filename}'.")
    files.download(output_filename)
# Out:
# Processing chunks from 26 to 30 (each with 143 sets)
# Set 3576 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3559
# Set 3577 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.4278
# Set 3578 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3864
# Set 3579 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3861
# Set 3580 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3614
# Set 3581 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.2094
# Set 3582 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0189
# Set 3583 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.0256
# Set 3584 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.0233
# Set 3585 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1400
# Set 3586 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.0169
# Set 3587 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0925
# Set 3588 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.1536
# Set 3589 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3803
# Set 3590 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3471
# Set 3591 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3470
# Set 3592 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3211
# Set 3593 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3852
# Set 3594 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3518
# Set 3595 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3517
# Set 3596 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3540
# Set 3597 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.0370
# Set 3598 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2131
# Set 3599 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1837
# Set 3600 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1639
# Set 3601 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0747
# Set 3602 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2106
# Set 3603 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1968
# Set 3604 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2548
# Set 3605 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3562
# Set 3606 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3285
# Set 3607 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3285
# Set 3608 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3307
# Set 3609 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3606
# Set 3610 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3326
# Set 3611 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3326
# Set 3612 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3348
# Set 3613 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.2395
# Set 3614 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.0400
# Set 3615 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0073
# Set 3616 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.0453
# Set 3617 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.1571
# Set 3618 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1728
# Set 3619 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1783
# Set 3620 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.1556
# Set 3621 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3761
# Set 3622 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3181
# Set 3623 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3186
# Set 3624 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3107
# Set 3625 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3813
# Set 3626 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3230
# Set 3627 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3234
# Set 3628 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3158
# Set 3629 evaluated. Best: (eps: 1, min_samples: 15), Score: 0.0399
# Set 3630 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2516
# Set 3631 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2062
# Set 3632 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2263
# Set 3633 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2545
# Set 3634 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2095
# Set 3635 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2010
# Set 3636 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2070
# Set 3637 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3430
# Set 3638 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2905
# Set 3639 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2908
# Set 3640 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2829
# Set 3641 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3477
# Set 3642 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3205
# Set 3643 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3206
# Set 3644 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3228
# Set 3645 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2586
# Set 3646 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2258
# Set 3647 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2062
# Set 3648 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2250
# Set 3649 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2365
# Set 3650 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1830
# Set 3651 evaluated. Best: (eps: 2, min_samples: 5), Score: 0
evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2760
# Set 4175 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2762
# Set 4176 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2320
# Set 4177 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1971
# Set 4178 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1936
# Set 4179 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1905
# Set 4180 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.1928
# Set 4181 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3290
# Set 4182 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3050
# Set 4183 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3051
# Set 4184 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3073
# Set 4185 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3332
# Set 4186 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3090
# Set 4187 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3091
# Set 4188 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.3112
# Set 4189 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.1839
# Set 4190 evaluated. Best: (eps: 1, min_samples: 5), Score: -0.1605
# Set 4191 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.0075
# Set 4192 evaluated. Best: (eps: 1, min_samples: 10), Score: 0.0067
# Set 4193 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.1389
# Set 4194 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2135
# Set 4195 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2718
# Set 4196 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.3030
# Set 4197 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3447
# Set 4198 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2988
# Set 4199 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2990
# Set 4200 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2885
# Set 4201 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3497
# Set 4202 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3034
# Set 4203 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.3036
# Set 4204 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2934
# Set 4205 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.1042
# Set 4206 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2561
# Set 4207 evaluated. Best: (eps: 1, min_samples: 10), Score: -0.2953
# Set 4208 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.3076
# Set 4209 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.3092
# Set 4210 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1946
# Set 4211 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1856
# Set 4212 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1901
# Set 4213 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3165
# Set 4214 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2742
# Set 4215 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2745
# Set 4216 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2643
# Set 4217 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3210
# Set 4218 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2976
# Set 4219 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2977
# Set 4220 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2998
# Set 4221 evaluated. Best: (eps: 1, min_samples: 15), Score: -0.2504
# Set 4222 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2049
# Set 4223 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.1916
# Set 4224 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2001
# Set 4225 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2062
# Set 4226 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1630
# Set 4227 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1599
# Set 4228 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1643
# Set 4229 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3020
# Set 4230 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2820
# Set 4231 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2821
# Set 4232 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2842
# Set 4233 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3059
# Set 4234 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2857
# Set 4235 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2859
# Set 4236 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2879
# Set 4237 evaluated. Best: (eps: 1, min_samples: 5), Score: 0.3070
# Set 4238 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2720
# Set 4239 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2716
# Set 4240 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2715
# Set 4241 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2687
# Set 4242 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2414
# Set 4243 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2411
# Set 4244 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2411
# Set 4245 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3017
# Set 4246 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2658
# Set 4247 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2655
# Set 4248 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2645
# Set 4249 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.3032
# Set 4250 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2673
# Set 4251 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2668
# Set 4252 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2661
# Set 4253 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2699
# Set 4254 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2424
# Set 4255 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2423
# Set 4256 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2422
# Set 4257 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2396
# Set 4258 evaluated. Best: (eps: 2, min_samples: 15), Score: 0.2044
# Set 4259 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2058
# Set 4260 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.1872
# Set 4261 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2666
# Set 4262 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2378
# Set 4263 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2377
# Set 4264 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2117
# Set 4265 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2683
# Set 4266 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2393
# Set 4267 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2391
# Set 4268 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2132
# Set 4269 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2411
# Set 4270 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2084
# Set 4271 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2187
# Set 4272 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2187
# Set 4273 evaluated. Best: (eps: 2, min_samples: 10), Score: 0.2055
# Set 4274 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.1992
# Set 4275 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.1991
# Set 4276 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.1991
# Set 4277 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2402
# Set 4278 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2144
# Set 4279 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2178
# Set 4280 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2181
# Set 4281 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2418
# Set 4282 evaluated. Best: (eps: 2, min_samples: 5), Score: 0.2160
# Set 4283 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2192
# Set 4284 evaluated. Best: (eps: 3, min_samples: 5), Score: 0.2195
# Chunk 30 processed and saved to 'DBSCAN_Coarse_Top10_chunk_30.csv'.
