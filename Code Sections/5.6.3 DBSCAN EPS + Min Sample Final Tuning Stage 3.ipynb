# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadbadi/Clustering_Frequency/blob/main/Code%20Sections/5.6.3%20DBSCAN%20EPS%20%2B%20Min%20Sample%20Final%20Tuning%20Stage%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **5.6.3 DBSCAN EPS + Min Sample Tuning: Stage 3 - Final Tuning**
# ### **Narrowest jumps of eps and min sample based on Stage 2 - APPROACH_2**

# %%
import warnings
import os
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from google.colab import files

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
url = "https://raw.githubusercontent.com/mohammadbadi/Clustering_Frequency/refs/heads/main/Output_CSV/FE_Encoded_New.csv" # URL of the dataset
data = pd.read_csv(url)                                                           # Read the dataset from URL
data = data.sample(frac=0.1, random_state=42)                                     # 10% Sample from the Dataset

                                                                                  # Set the range of chunks to process
start_chunk = 29                                                                  # Beginning value of Range
end_chunk = 30                                                                    # End Value of Range

expected_filenames = [f"DBSCAN_Intermediate_Top10_chunk_{i}.csv" for i in range(start_chunk, end_chunk + 1)]

                                                                                  # Check for missing files in the Colab environment
missing_files = [fname for fname in expected_filenames if not os.path.exists(fname)]
if missing_files:
    print(f"Error: The following expected files were not found: {missing_files}")
else:
    print("All expected files found. Processing...")

for expected_filename in expected_filenames:
    if not os.path.exists(expected_filename):
        continue

    intermediate_df = pd.read_csv(expected_filename)
    final_results = []

    for idx, row in intermediate_df.iterrows():
        set_number = row["set_number"]
        feature_set = eval(row["features"])
        if pd.isnull(row["best_eps"]) or pd.isnull(row["best_min_samples"]):
            continue

        top10_eps_list = eval(row["top10_eps"])
        top10_min_samples_list = eval(row["top10_min_samples"])

        eps_min, eps_max = min(top10_eps_list), max(top10_eps_list)
        eps_grid_fine = np.arange(eps_min, eps_max + 0.1, 0.1)

        ms_min, ms_max = min(top10_min_samples_list), max(top10_min_samples_list)
        min_samples_grid_fine = list(range(int(ms_min), int(ms_max) + 1))

        missing_features = [feat for feat in feature_set if feat not in data.columns]
        if missing_features:
            continue

        df_subset = data[feature_set]
        df_subset = pd.DataFrame(StandardScaler().fit_transform(df_subset), columns=df_subset.columns)

        score_list = []
        for eps in eps_grid_fine:
            for min_samples in min_samples_grid_fine:
                try:
                    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
                    labels = dbscan.fit_predict(df_subset)
                    if len(set(labels)) > 1 and any(label != -1 for label in labels):
                        score = silhouette_score(df_subset, labels)
                        score_list.append((score, eps, min_samples))
                except Exception:
                    continue

        if score_list:
            score_list.sort(key=lambda x: x[0], reverse=True)
            best_score, best_eps, best_min_samples = score_list[0]
            final_results.append({
                "set_number": set_number,
                "features": feature_set,
                "best_eps": best_eps,
                "best_min_samples": best_min_samples,
                "best_silhouette_score": best_score
            })
            print(f"Fine tuning: Set {set_number} processed. Best: (eps: {best_eps}, min_samples: {best_min_samples}), Score: {best_score:.4f}")
        else:
            final_results.append({
                "set_number": set_number,
                "features": feature_set,
                "best_eps": None,
                "best_min_samples": None,
                "best_silhouette_score": None
            })
            print(f"Fine tuning: Set {set_number} processed. No valid clustering found.")

    final_df = pd.DataFrame(final_results)
    output_filename = expected_filename.replace("Intermediate_Top10", "Best_Fine_Params")
    final_df.to_csv(output_filename, index=False)
    print(f"\nFine tuning for '{expected_filename}' complete. Final best parameters saved to '{output_filename}'.")

    files.download(output_filename)                                               # Download the dataframe as csv file
# Out:
# All expected files found. Processing...
# Fine tuning: Set 4005 processed. Best: (eps: 0.7999999999999999, min_samples: 3), Score: 0.4320
# Fine tuning: Set 4006 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3880
# Fine tuning: Set 4007 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3876
# Fine tuning: Set 4008 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3899
# Fine tuning: Set 4009 processed. Best: (eps: 0.7999999999999999, min_samples: 3), Score: 0.4377
# Fine tuning: Set 4010 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3933
# Fine tuning: Set 4011 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3928
# Fine tuning: Set 4012 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3951
# Fine tuning: Set 4014 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2371
# Fine tuning: Set 4015 processed. Best: (eps: 1.1999999999999997, min_samples: 3), Score: 0.2312
# Fine tuning: Set 4016 processed. Best: (eps: 1.0999999999999999, min_samples: 3), Score: 0.2304
# Fine tuning: Set 4017 processed. Best: (eps: 1.0999999999999999, min_samples: 3), Score: 0.1743
# Fine tuning: Set 4018 processed. Best: (eps: 1.5, min_samples: 13), Score: 0.2060
# Fine tuning: Set 4019 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.1988
# Fine tuning: Set 4020 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.1989
# Fine tuning: Set 4021 processed. Best: (eps: 0.9999999999999999, min_samples: 3), Score: 0.3868
# Fine tuning: Set 4022 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3518
# Fine tuning: Set 4023 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3517
# Fine tuning: Set 4024 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.3539
# Fine tuning: Set 4025 processed. Best: (eps: 0.8999999999999999, min_samples: 3), Score: 0.3918
# Fine tuning: Set 4026 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3565
# Fine tuning: Set 4027 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3564
# Fine tuning: Set 4028 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3586
# Fine tuning: Set 4029 processed. Best: (eps: 1.0999999999999999, min_samples: 16), Score: 0.2624
# Fine tuning: Set 4030 processed. Best: (eps: 1.5, min_samples: 14), Score: 0.2002
# Fine tuning: Set 4031 processed. Best: (eps: 1.4, min_samples: 3), Score: 0.2028
# Fine tuning: Set 4032 processed. Best: (eps: 1.4, min_samples: 3), Score: 0.2022
# Fine tuning: Set 4033 processed. Best: (eps: 0.9999999999999999, min_samples: 11), Score: 0.1540
# Fine tuning: Set 4034 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.1692
# Fine tuning: Set 4035 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.1787
# Fine tuning: Set 4036 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.1787
# Fine tuning: Set 4037 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3610
# Fine tuning: Set 4038 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3320
# Fine tuning: Set 4039 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3319
# Fine tuning: Set 4040 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3341
# Fine tuning: Set 4041 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3654
# Fine tuning: Set 4042 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3362
# Fine tuning: Set 4043 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3361
# Fine tuning: Set 4044 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3382
# Fine tuning: Set 4046 processed. Best: (eps: 1.2999999999999998, min_samples: 3), Score: 0.2365
# Fine tuning: Set 4047 processed. Best: (eps: 1.1999999999999997, min_samples: 8), Score: 0.2295
# Fine tuning: Set 4048 processed. Best: (eps: 1.1999999999999997, min_samples: 3), Score: 0.2292
# Fine tuning: Set 4049 processed. Best: (eps: 0.9999999999999999, min_samples: 10), Score: 0.1969
# Fine tuning: Set 4050 processed. Best: (eps: 1.6, min_samples: 16), Score: 0.2641
# Fine tuning: Set 4051 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.1980
# Fine tuning: Set 4052 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.1985
# Fine tuning: Set 4053 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3823
# Fine tuning: Set 4054 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3480
# Fine tuning: Set 4055 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3479
# Fine tuning: Set 4056 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3501
# Fine tuning: Set 4057 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3876
# Fine tuning: Set 4058 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3530
# Fine tuning: Set 4059 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3528
# Fine tuning: Set 4060 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3550
# Fine tuning: Set 4061 processed. Best: (eps: 0.9999999999999999, min_samples: 8), Score: 0.2065
# Fine tuning: Set 4062 processed. Best: (eps: 1.6, min_samples: 6), Score: 0.2488
# Fine tuning: Set 4063 processed. Best: (eps: 1.4, min_samples: 8), Score: 0.1942
# Fine tuning: Set 4064 processed. Best: (eps: 1.4, min_samples: 9), Score: 0.1895
# Fine tuning: Set 4065 processed. Best: (eps: 1.3, min_samples: 3), Score: 0.1785
# Fine tuning: Set 4066 processed. Best: (eps: 1.6, min_samples: 9), Score: 0.1940
# Fine tuning: Set 4067 processed. Best: (eps: 1.5, min_samples: 5), Score: 0.1594
# Fine tuning: Set 4068 processed. Best: (eps: 1.5, min_samples: 5), Score: 0.1586
# Fine tuning: Set 4069 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3473
# Fine tuning: Set 4070 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3193
# Fine tuning: Set 4071 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3193
# Fine tuning: Set 4072 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.3215
# Fine tuning: Set 4073 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3521
# Fine tuning: Set 4074 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3238
# Fine tuning: Set 4075 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3238
# Fine tuning: Set 4076 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3259
# Fine tuning: Set 4077 processed. Best: (eps: 1.0999999999999999, min_samples: 6), Score: 0.1763
# Fine tuning: Set 4078 processed. Best: (eps: 1.6, min_samples: 13), Score: 0.1860
# Fine tuning: Set 4079 processed. Best: (eps: 1.6, min_samples: 13), Score: 0.1606
# Fine tuning: Set 4080 processed. Best: (eps: 1.6, min_samples: 13), Score: 0.1614
# Fine tuning: Set 4081 processed. Best: (eps: 1.1999999999999997, min_samples: 9), Score: 0.1439
# Fine tuning: Set 4082 processed. Best: (eps: 2.0000000000000004, min_samples: 14), Score: 0.1988
# Fine tuning: Set 4083 processed. Best: (eps: 1.9000000000000004, min_samples: 8), Score: 0.1882
# Fine tuning: Set 4084 processed. Best: (eps: 2.1000000000000005, min_samples: 16), Score: 0.1900
# Fine tuning: Set 4085 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3282
# Fine tuning: Set 4086 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3044
# Fine tuning: Set 4087 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3045
# Fine tuning: Set 4088 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3066
# Fine tuning: Set 4089 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3324
# Fine tuning: Set 4090 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3084
# Fine tuning: Set 4091 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3085
# Fine tuning: Set 4092 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3105
# Fine tuning: Set 4093 processed. Best: (eps: 0.6, min_samples: 3), Score: 0.3573
# Fine tuning: Set 4094 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3112
# Fine tuning: Set 4095 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3103
# Fine tuning: Set 4096 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3100
# Fine tuning: Set 4097 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3060
# Fine tuning: Set 4098 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.2714
# Fine tuning: Set 4099 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.2709
# Fine tuning: Set 4100 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2707
# Fine tuning: Set 4101 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3498
# Fine tuning: Set 4102 processed. Best: (eps: 2.1000000000000005, min_samples: 13), Score: 0.3042
# Fine tuning: Set 4103 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3048
# Fine tuning: Set 4104 processed. Best: (eps: 2.600000000000001, min_samples: 13), Score: 0.3049
# Fine tuning: Set 4105 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3518
# Fine tuning: Set 4106 processed. Best: (eps: 2.1000000000000005, min_samples: 13), Score: 0.3059
# Fine tuning: Set 4107 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.3064
# Fine tuning: Set 4108 processed. Best: (eps: 2.600000000000001, min_samples: 13), Score: 0.3064
# Fine tuning: Set 4109 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3077
# Fine tuning: Set 4110 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.2727
# Fine tuning: Set 4111 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.2724
# Fine tuning: Set 4112 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2722
# Fine tuning: Set 4113 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2686
# Fine tuning: Set 4114 processed. Best: (eps: 1.8000000000000003, min_samples: 3), Score: 0.2415
# Fine tuning: Set 4115 processed. Best: (eps: 2.2000000000000006, min_samples: 8), Score: 0.2412
# Fine tuning: Set 4116 processed. Best: (eps: 2.2000000000000006, min_samples: 13), Score: 0.2411
# Fine tuning: Set 4117 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3037
# Fine tuning: Set 4118 processed. Best: (eps: 2.1000000000000005, min_samples: 13), Score: 0.2679
# Fine tuning: Set 4119 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2691
# Fine tuning: Set 4120 processed. Best: (eps: 2.0000000000000004, min_samples: 16), Score: 0.2676
# Fine tuning: Set 4121 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3057
# Fine tuning: Set 4122 processed. Best: (eps: 2.1000000000000005, min_samples: 13), Score: 0.2697
# Fine tuning: Set 4123 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2707
# Fine tuning: Set 4124 processed. Best: (eps: 2.500000000000001, min_samples: 8), Score: 0.2707
# Fine tuning: Set 4125 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2707
# Fine tuning: Set 4126 processed. Best: (eps: 2.1000000000000005, min_samples: 13), Score: 0.2432
# Fine tuning: Set 4127 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.2430
# Fine tuning: Set 4128 processed. Best: (eps: 2.3000000000000007, min_samples: 13), Score: 0.2429
# Fine tuning: Set 4129 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.2416
# Fine tuning: Set 4130 processed. Best: (eps: 2.400000000000001, min_samples: 13), Score: 0.2192
# Fine tuning: Set 4131 processed. Best: (eps: 2.400000000000001, min_samples: 13), Score: 0.2191
# Fine tuning: Set 4132 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.2190
# Fine tuning: Set 4133 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2703
# Fine tuning: Set 4134 processed. Best: (eps: 2.2000000000000006, min_samples: 13), Score: 0.2405
# Fine tuning: Set 4135 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2423
# Fine tuning: Set 4136 processed. Best: (eps: 2.3000000000000007, min_samples: 16), Score: 0.2402
# Fine tuning: Set 4137 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2721
# Fine tuning: Set 4138 processed. Best: (eps: 2.2000000000000006, min_samples: 13), Score: 0.2422
# Fine tuning: Set 4139 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2440
# Fine tuning: Set 4140 processed. Best: (eps: 2.500000000000001, min_samples: 8), Score: 0.2441
# Fine tuning: Set 4142 processed. Best: (eps: 1.2999999999999998, min_samples: 8), Score: 0.2351
# Fine tuning: Set 4143 processed. Best: (eps: 1.1999999999999997, min_samples: 8), Score: 0.2279
# Fine tuning: Set 4144 processed. Best: (eps: 1.1999999999999997, min_samples: 3), Score: 0.2277
# Fine tuning: Set 4145 processed. Best: (eps: 1.0999999999999999, min_samples: 5), Score: 0.2319
# Fine tuning: Set 4146 processed. Best: (eps: 1.2999999999999998, min_samples: 3), Score: 0.1818
# Fine tuning: Set 4147 processed. Best: (eps: 1.5, min_samples: 16), Score: 0.1714
#
# Fine tuning for 'DBSCAN_Intermediate_Top10_chunk_29.csv' complete. Final best parameters saved to 'DBSCAN_Best_Fine_Params_chunk_29.csv'.
# Fine tuning: Set 4148 processed. Best: (eps: 1.6, min_samples: 8), Score: 0.1969
# Fine tuning: Set 4149 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3836
# Fine tuning: Set 4150 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3490
# Fine tuning: Set 4151 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3489
# Fine tuning: Set 4152 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.3512
# Fine tuning: Set 4153 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3889
# Fine tuning: Set 4154 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3539
# Fine tuning: Set 4155 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3538
# Fine tuning: Set 4156 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.3561
# Fine tuning: Set 4157 processed. Best: (eps: 0.9999999999999999, min_samples: 4), Score: 0.2287
# Fine tuning: Set 4158 processed. Best: (eps: 1.6, min_samples: 4), Score: 0.2313
# Fine tuning: Set 4159 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.2006
# Fine tuning: Set 4160 processed. Best: (eps: 1.5, min_samples: 13), Score: 0.1842
# Fine tuning: Set 4161 processed. Best: (eps: 1.4, min_samples: 10), Score: 0.2022
# Fine tuning: Set 4162 processed. Best: (eps: 1.5, min_samples: 13), Score: 0.1472
# Fine tuning: Set 4163 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.1598
# Fine tuning: Set 4164 processed. Best: (eps: 1.5, min_samples: 13), Score: 0.1432
# Fine tuning: Set 4165 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3483
# Fine tuning: Set 4166 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3201
# Fine tuning: Set 4167 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3201
# Fine tuning: Set 4168 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.3224
# Fine tuning: Set 4169 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3531
# Fine tuning: Set 4170 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3245
# Fine tuning: Set 4171 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3245
# Fine tuning: Set 4172 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3268
# Fine tuning: Set 4173 processed. Best: (eps: 1.2999999999999998, min_samples: 3), Score: 0.1853
# Fine tuning: Set 4174 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.1596
# Fine tuning: Set 4175 processed. Best: (eps: 1.6, min_samples: 14), Score: 0.1552
# Fine tuning: Set 4176 processed. Best: (eps: 2.0000000000000004, min_samples: 13), Score: 0.2320
# Fine tuning: Set 4177 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.1617
# Fine tuning: Set 4178 processed. Best: (eps: 2.0000000000000004, min_samples: 15), Score: 0.1936
# Fine tuning: Set 4179 processed. Best: (eps: 2.1000000000000005, min_samples: 16), Score: 0.1986
# Fine tuning: Set 4180 processed. Best: (eps: 2.1000000000000005, min_samples: 17), Score: 0.2044
# Fine tuning: Set 4181 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3290
# Fine tuning: Set 4182 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3050
# Fine tuning: Set 4183 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3051
# Fine tuning: Set 4184 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3073
# Fine tuning: Set 4185 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3332
# Fine tuning: Set 4186 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3090
# Fine tuning: Set 4187 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.3091
# Fine tuning: Set 4188 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.3112
# Fine tuning: Set 4189 processed. Best: (eps: 1.0999999999999999, min_samples: 8), Score: 0.2639
# Fine tuning: Set 4190 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2059
# Fine tuning: Set 4191 processed. Best: (eps: 1.5, min_samples: 17), Score: 0.1792
# Fine tuning: Set 4192 processed. Best: (eps: 1.6, min_samples: 8), Score: 0.1989
# Fine tuning: Set 4193 processed. Best: (eps: 1.5, min_samples: 8), Score: 0.2099
# Fine tuning: Set 4194 processed. Best: (eps: 1.5, min_samples: 13), Score: 0.1452
# Fine tuning: Set 4195 processed. Best: (eps: 1.6, min_samples: 13), Score: 0.1495
# Fine tuning: Set 4196 processed. Best: (eps: 1.5, min_samples: 10), Score: 0.1466
# Fine tuning: Set 4197 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3447
# Fine tuning: Set 4198 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.3170
# Fine tuning: Set 4199 processed. Best: (eps: 2.2000000000000006, min_samples: 8), Score: 0.3170
# Fine tuning: Set 4200 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.3192
# Fine tuning: Set 4201 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3497
# Fine tuning: Set 4202 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.3216
# Fine tuning: Set 4203 processed. Best: (eps: 2.2000000000000006, min_samples: 8), Score: 0.3216
# Fine tuning: Set 4204 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.3238
# Fine tuning: Set 4205 processed. Best: (eps: 1.5, min_samples: 16), Score: 0.2429
# Fine tuning: Set 4206 processed. Best: (eps: 1.6, min_samples: 17), Score: 0.1823
# Fine tuning: Set 4207 processed. Best: (eps: 1.5, min_samples: 10), Score: 0.1514
# Fine tuning: Set 4208 processed. Best: (eps: 1.6, min_samples: 13), Score: 0.1541
# Fine tuning: Set 4209 processed. Best: (eps: 1.5, min_samples: 13), Score: 0.1523
# Fine tuning: Set 4210 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2191
# Fine tuning: Set 4211 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.1976
# Fine tuning: Set 4212 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2129
# Fine tuning: Set 4213 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3165
# Fine tuning: Set 4214 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.2934
# Fine tuning: Set 4215 processed. Best: (eps: 2.2000000000000006, min_samples: 8), Score: 0.2935
# Fine tuning: Set 4216 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.2957
# Fine tuning: Set 4217 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.3210
# Fine tuning: Set 4218 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2976
# Fine tuning: Set 4219 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2977
# Fine tuning: Set 4220 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2998
# Fine tuning: Set 4221 processed. Best: (eps: 1.6, min_samples: 13), Score: 0.1861
# Fine tuning: Set 4222 processed. Best: (eps: 2.2000000000000006, min_samples: 11), Score: 0.2266
# Fine tuning: Set 4223 processed. Best: (eps: 2.2000000000000006, min_samples: 11), Score: 0.2234
# Fine tuning: Set 4224 processed. Best: (eps: 2.2000000000000006, min_samples: 11), Score: 0.2279
# Fine tuning: Set 4225 processed. Best: (eps: 2.0000000000000004, min_samples: 15), Score: 0.2062
# Fine tuning: Set 4226 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.1973
# Fine tuning: Set 4227 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.1768
# Fine tuning: Set 4228 processed. Best: (eps: 2.1000000000000005, min_samples: 3), Score: 0.1758
# Fine tuning: Set 4229 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3020
# Fine tuning: Set 4230 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2820
# Fine tuning: Set 4231 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2821
# Fine tuning: Set 4232 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2842
# Fine tuning: Set 4233 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.3059
# Fine tuning: Set 4234 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2857
# Fine tuning: Set 4235 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2859
# Fine tuning: Set 4236 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2879
# Fine tuning: Set 4237 processed. Best: (eps: 0.9999999999999999, min_samples: 3), Score: 0.3070
# Fine tuning: Set 4238 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.2720
# Fine tuning: Set 4239 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.2716
# Fine tuning: Set 4240 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2715
# Fine tuning: Set 4241 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2687
# Fine tuning: Set 4242 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2414
# Fine tuning: Set 4243 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2411
# Fine tuning: Set 4244 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2411
# Fine tuning: Set 4245 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3017
# Fine tuning: Set 4246 processed. Best: (eps: 2.1000000000000005, min_samples: 6), Score: 0.2660
# Fine tuning: Set 4247 processed. Best: (eps: 2.3000000000000007, min_samples: 3), Score: 0.2675
# Fine tuning: Set 4248 processed. Best: (eps: 2.3000000000000007, min_samples: 13), Score: 0.2657
# Fine tuning: Set 4249 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.3032
# Fine tuning: Set 4250 processed. Best: (eps: 2.2000000000000006, min_samples: 12), Score: 0.2675
# Fine tuning: Set 4251 processed. Best: (eps: 2.3000000000000007, min_samples: 3), Score: 0.2687
# Fine tuning: Set 4252 processed. Best: (eps: 2.2000000000000006, min_samples: 15), Score: 0.2674
# Fine tuning: Set 4253 processed. Best: (eps: 1.5, min_samples: 3), Score: 0.2699
# Fine tuning: Set 4254 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2424
# Fine tuning: Set 4255 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2423
# Fine tuning: Set 4256 processed. Best: (eps: 2.0000000000000004, min_samples: 3), Score: 0.2422
# Fine tuning: Set 4257 processed. Best: (eps: 1.7000000000000002, min_samples: 3), Score: 0.2396
# Fine tuning: Set 4258 processed. Best: (eps: 2.3000000000000007, min_samples: 13), Score: 0.2175
# Fine tuning: Set 4259 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.2174
# Fine tuning: Set 4260 processed. Best: (eps: 2.2000000000000006, min_samples: 3), Score: 0.2174
# Fine tuning: Set 4261 processed. Best: (eps: 1.8000000000000003, min_samples: 3), Score: 0.2666
# Fine tuning: Set 4262 processed. Best: (eps: 2.0000000000000004, min_samples: 5), Score: 0.2378
# Fine tuning: Set 4263 processed. Best: (eps: 2.3000000000000007, min_samples: 3), Score: 0.2394
# Fine tuning: Set 4264 processed. Best: (eps: 2.500000000000001, min_samples: 3), Score: 0.2396
# Fine tuning: Set 4265 processed. Best: (eps: 1.8000000000000003, min_samples: 3), Score: 0.2683
# Fine tuning: Set 4266 processed. Best: (eps: 2.0000000000000004, min_samples: 5), Score: 0.2393
# Fine tuning: Set 4267 processed. Best: (eps: 2.3000000000000007, min_samples: 3), Score: 0.2409
# Fine tuning: Set 4268 processed. Best: (eps: 2.500000000000001, min_samples: 3), Score: 0.2410
# Fine tuning: Set 4269 processed. Best: (eps: 1.6, min_samples: 3), Score: 0.2411
# Fine tuning: Set 4270 processed. Best: (eps: 2.400000000000001, min_samples: 8), Score: 0.2188
# Fine tuning: Set 4271 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2187
# Fine tuning: Set 4272 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2187
# Fine tuning: Set 4273 processed. Best: (eps: 2.1000000000000005, min_samples: 8), Score: 0.2176
# Fine tuning: Set 4274 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.1992
# Fine tuning: Set 4275 processed. Best: (eps: 2.6, min_samples: 3), Score: 0.1991
# Fine tuning: Set 4276 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.1991
# Fine tuning: Set 4277 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.2402
# Fine tuning: Set 4278 processed. Best: (eps: 2.2000000000000006, min_samples: 5), Score: 0.2162
# Fine tuning: Set 4279 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2178
# Fine tuning: Set 4280 processed. Best: (eps: 2.5, min_samples: 3), Score: 0.2181
# Fine tuning: Set 4281 processed. Best: (eps: 1.9000000000000004, min_samples: 3), Score: 0.2418
# Fine tuning: Set 4282 processed. Best: (eps: 2.2000000000000006, min_samples: 5), Score: 0.2177
# Fine tuning: Set 4283 processed. Best: (eps: 3.1000000000000005, min_samples: 3), Score: 0.2504
# Fine tuning: Set 4284 processed. Best: (eps: 3.1000000000000005, min_samples: 3), Score: 0.2523
#
# Fine tuning for 'DBSCAN_Intermediate_Top10_chunk_30.csv' complete. Final best parameters saved to 'DBSCAN_Best_Fine_Params_chunk_30.csv'.
